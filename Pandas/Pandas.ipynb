# %% [markdown]
# # Exploring Pandas

# %%
import pandas as pd

# %%
#reading a csv file
customer_data = pd.read_csv('CUSTOMER_DATA.csv',encoding = "ISO-8859-1")

# %%
customer_data.head()
# Out:
#   CustomerID                         CustomerName          ContactName  \
# 0          1                  Alfreds Futterkiste        Maria Anders
# 1         2   Ana Trujillo Emparedados y helados         Ana Trujillo
# 2         3              Antonio Moreno Taquería       Antonio Moreno
# 3         4                      Around the Horn         Thomas Hardy
# 4         5                   Berglunds snabbköp   Christina Berglund
#
#                           Address          City PostalCode   Country
# 0                  Obere Str. 57        Berlin      12209   Germany
# 1  Avda. de la Constitución 2222   México D.F.      05021    Mexico
# 2                 Mataderos 2312   México D.F.      05023    Mexico
# 3                120 Hanover Sq.        London    WA1 1DP        UK
# 4                 Berguvsvägen 8         Luleå   S-958 22    Sweden

# %%
customer_data.tail()
# Out:
#    CustomerID             CustomerName        ContactName  \
# 86        87           Wartian Herkku   Pirkko Koskitalo
# 87        88   Wellington Importadora      Paula Parente
# 88        89     White Clover Markets     Karl Jablonski
# 89        90              Wilman Kala    Matti Karttunen
# 90        91                   Wolski            Zbyszek
#
#                          Address       City  PostalCode   Country
# 86                  Torikatu 38       Oulu       90110   Finland
# 87           Rua do Mercado, 12    Resende   08737-363    Brazil
# 88  305 - 14th Ave. S. Suite 3B    Seattle       98128       USA
# 89                Keskuskatu 45   Helsinki       21240   Finland
# 90              ul. Filtrowa 68      Walla      01-012    Poland

# %%
customer_data.shape
# Out:
# (91, 7)

# %%
#using iloc selecting first five rows and all columns
customer_data.iloc[0:5,:]
# Out:
#   CustomerID                         CustomerName          ContactName  \
# 0          1                  Alfreds Futterkiste        Maria Anders
# 1         2   Ana Trujillo Emparedados y helados         Ana Trujillo
# 2         3              Antonio Moreno Taquería       Antonio Moreno
# 3         4                      Around the Horn         Thomas Hardy
# 4         5                   Berglunds snabbköp   Christina Berglund
#
#                           Address          City PostalCode   Country
# 0                  Obere Str. 57        Berlin      12209   Germany
# 1  Avda. de la Constitución 2222   México D.F.      05021    Mexico
# 2                 Mataderos 2312   México D.F.      05023    Mexico
# 3                120 Hanover Sq.        London    WA1 1DP        UK
# 4                 Berguvsvägen 8         Luleå   S-958 22    Sweden

# %%
#using iloc selecting first five rows and first and second columns
customer_data.iloc[0:5,0:2]
# Out:
#   CustomerID                         CustomerName
# 0          1                  Alfreds Futterkiste
# 1         2   Ana Trujillo Emparedados y helados
# 2         3              Antonio Moreno Taquería
# 3         4                      Around the Horn
# 4         5                   Berglunds snabbköp

# %%
customer_data.loc[0:5,["CustomerID","CustomerName"]]
# Out:
#   CustomerID                         CustomerName
# 0          1                  Alfreds Futterkiste
# 1         2   Ana Trujillo Emparedados y helados
# 2         3              Antonio Moreno Taquería
# 3         4                      Around the Horn
# 4         5                   Berglunds snabbköp
# 5         6              Blauer See Delikatessen

# %%
customer_data[["CustomerID","CustomerName"]]
# Out:
#    CustomerID                           CustomerName
# 0           1                    Alfreds Futterkiste
# 1          2     Ana Trujillo Emparedados y helados
# 2          3                Antonio Moreno Taquería
# 3          4                        Around the Horn
# 4          5                     Berglunds snabbköp
# 5          6                Blauer See Delikatessen
# 6          7                   Blondel père et fils
# 7          8              Bólido Comidas preparadas
# 8          9                               Bon app'
# 9         10                 Bottom-Dollar Marketse
# 10        11                          B's Beverages
# 11        12             Cactus Comidas para llevar
# 12        13             Centro comercial Moctezuma
# 13        14                      Chop-suey Chinese
# 14        15                       Comércio Mineiro
# 15        16                  Consolidated Holdings
# 16        17              Drachenblut Delikatessend
# ...

# %%
type(customer_data["Country"])
# Out:
# pandas.core.series.Series

# %%
frame = pd.DataFrame(
    [
        [1,2],
        ["Boris Yeltsin", "Mikhail Gorbachev"]
    ],
    index=["row1", "row2"],
    columns=["column1", "column2"]
)
frame
# Out:
#             column1            column2
# row1              1                  2
# row2  Boris Yeltsin  Mikhail Gorbachev

# %%
customer_data["Country"].head()
# Out:
# 0    Germany
# 1     Mexico
# 2     Mexico
# 3         UK
# 4     Sweden
# Name: Country, dtype: object

# %%
customer_data["CustomerID"].count()
# min max mean median std corr
# Out:
# 91

# %%
customer_data.describe()
# Out:
#        CustomerID           CustomerName    ContactName          Address  \
# count          91                     91             91               91
# unique         91                     91             91               91
# top           33   Blondel père et fils   Pedro Afonso   C/ Araquil, 67
# freq            1                      1              1                1
#
#            City PostalCode Country
# count        91         90      91
# unique       69         86      21
# top     London       1010     USA
# freq          6          3      13

# %%
customer_data[customer_data['PostalCode']=='USA']
# Out:
# Empty DataFrame
# Columns: [CustomerID, CustomerName, ContactName, Address, City, PostalCode, Country]
# Index: []

# %%
customer_data.sort_values('Country')
# Out:
#    CustomerID                        CustomerName          ContactName  \
# 53        54              Océano Atlántico Ltda.       Yvonne Moncada
# 63        64                       Rancho grande     Sergio Gutiérrez
# 11        12          Cactus Comidas para llevar     Patricio Simpson
# 19        20                        Ernst Handel        Roland Mendel
# 58        59                    Piccolo und mehr          Georg Pipps
# 75        76                    Suprêmes délices     Pascale Cartrain
# 49        50                        Maison Dewey      Catherine Dewey
# 33        34                       Hanari Carnes         Mario Pontes
# 66        67                  Ricardo Adocicados       Janete Limeira
# 30        31                 Gourmet Lanchonetes        André Fonseca
# 61        62                       Queen Cozinha       Lúcia Carvalho
# 60        61                         Que Delícia     Bernardo Batista
# ...
